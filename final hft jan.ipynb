# %%
pip install yahoo-finance
# Out:
# Requirement already satisfied: yahoo-finance in /Users/nesrine/opt/anaconda3/lib/python3.9/site-packages (1.4.0)
# Requirement already satisfied: pytz in /Users/nesrine/opt/anaconda3/lib/python3.9/site-packages (from yahoo-finance) (2022.7)
# Requirement already satisfied: simplejson in /Users/nesrine/opt/anaconda3/lib/python3.9/site-packages (from yahoo-finance) (3.18.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
BTC = yf.download('BTC-USD', start='2022-12-22', end='2022-12-23',  interval = '1m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
BTC.head()
# Out:
#                              Open          High           Low         Close  \
# Datetime
# 2022-12-22 00:00:00  16818.380859  16818.380859  16818.380859  16818.380859
# 2022-12-22 00:01:00  16825.763672  16825.763672  16825.763672  16825.763672
# 2022-12-22 00:02:00  16824.031250  16824.031250  16824.031250  16824.031250
# 2022-12-22 00:03:00  16829.160156  16829.160156  16829.160156  16829.160156
# 2022-12-22 00:04:00  16829.492188  16829.492188  16829.492188  16829.492188
#
#                         Adj Close   Volume
# Datetime
# 2022-12-22 00:00:00  16818.380859        0
# 2022-12-22 00:01:00  16825.763672        0
# 2022-12-22 00:02:00  16824.031250  1409024
# 2022-12-22 00:03:00  16829.160156        0
# 2022-12-22 00:04:00  16829.492188        0

# %%
BTC
# Out:
#                              Open          High           Low         Close  \
# Datetime
# 2022-12-22 00:00:00  16818.380859  16818.380859  16818.380859  16818.380859
# 2022-12-22 00:01:00  16825.763672  16825.763672  16825.763672  16825.763672
# 2022-12-22 00:02:00  16824.031250  16824.031250  16824.031250  16824.031250
# 2022-12-22 00:03:00  16829.160156  16829.160156  16829.160156  16829.160156
# 2022-12-22 00:04:00  16829.492188  16829.492188  16829.492188  16829.492188
# ...                           ...           ...           ...           ...
# 2022-12-22 23:54:00  16829.533203  16829.533203  16829.533203  16829.533203
# 2022-12-22 23:55:00  16828.492188  16828.492188  16828.492188  16828.492188
# 2022-12-22 23:56:00  16829.121094  16829.121094  16829.121094  16829.121094
# 2022-12-22 23:57:00  16828.197266  16828.197266  16828.197266  16828.197266
# 2022-12-22 23:58:00  16829.089844  16829.089844  16829.089844  16829.089844
#
#                         Adj Close    Volume
# Datetime
# 2022-12-22 00:00:00  16818.380859         0
# 2022-12-22 00:01:00  16825.763672         0
# 2022-12-22 00:02:00  16824.031250   1409024
# 2022-12-22 00:03:00  16829.160156         0
# 2022-12-22 00:04:00  16829.492188         0
# ...                           ...       ...
# 2022-12-22 23:54:00  16829.533203   1167360
# 2022-12-22 23:55:00  16828.492188  17562624
# 2022-12-22 23:56:00  16829.121094         0
# 2022-12-22 23:57:00  16828.197266         0
# 2022-12-22 23:58:00  16829.089844         0
#
# [1434 rows x 6 columns]

# %%
ETH = yf.download('ETH-USD', start='2022-12-22', end='2022-12-23',  interval = '1m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ETH
# Out:
#                             Open         High          Low        Close  \
# Datetime
# 2022-12-22 00:00:00  1213.672607  1213.672607  1213.672607  1213.672607
# 2022-12-22 00:01:00  1214.051025  1214.051025  1214.051025  1214.051025
# 2022-12-22 00:02:00  1213.826782  1213.826782  1213.826782  1213.826782
# 2022-12-22 00:03:00  1214.177002  1214.177002  1214.177002  1214.177002
# 2022-12-22 00:04:00  1214.120728  1214.120728  1214.120728  1214.120728
# ...                          ...          ...          ...          ...
# 2022-12-22 23:54:00  1218.223511  1218.223511  1218.223511  1218.223511
# 2022-12-22 23:55:00  1218.341797  1218.341797  1218.341797  1218.341797
# 2022-12-22 23:56:00  1218.353638  1218.353638  1218.353638  1218.353638
# 2022-12-22 23:57:00  1218.216064  1218.216064  1218.216064  1218.216064
# 2022-12-22 23:58:00  1218.134766  1218.134766  1218.134766  1218.134766
#
#                        Adj Close   Volume
# Datetime
# 2022-12-22 00:00:00  1213.672607        0
# 2022-12-22 00:01:00  1214.051025        0
# 2022-12-22 00:02:00  1213.826782        0
# 2022-12-22 00:03:00  1214.177002     5888
# 2022-12-22 00:04:00  1214.120728        0
# ...                          ...      ...
# 2022-12-22 23:54:00  1218.223511   523776
# 2022-12-22 23:55:00  1218.341797  4136960
# 2022-12-22 23:56:00  1218.353638   508416
# 2022-12-22 23:57:00  1218.216064  1118208
# 2022-12-22 23:58:00  1218.134766        0
#
# [1434 rows x 6 columns]

# %%
S1_0 = BTC['Open'][0]
S2_0 = ETH['Open'][0]

# %%
S1_0
# Out:
# 16818.380859375

# %%
S2_0
# Out:
# 1213.672607421875

# %%
lr1 = np.log(BTC['Adj Close'] / BTC['Adj Close'].shift(1))
lr2 = np.log(ETH['Adj Close'] / ETH['Adj Close'].shift(1))
mu_1 = lr1.mean() * 390
mu_2 = lr2.mean() * 390
sigma_1 = lr1.std() * np.sqrt(390)
sigma_2 = lr2.std() * np.sqrt(390)
rho = lr1.corr(lr2)
z_0 = 0.00
gamma = 0.5
delta =1
T = 1
M = len(BTC)

# %%
result = linregress(np.log(BTC['Adj Close']), np.log(ETH['Adj Close']))
beta = result.slope

# %%
dt = T/M
S1 = np.zeros((M + 1, 1))
S2 = np.zeros((M + 1, 1))
z =  np.zeros((M + 1, 1))
a =  np.zeros((M + 1, 1))
b =  np.zeros((M + 1, 1))
c =  np.zeros((M + 1, 1))
Pi_1 = np.zeros((M + 1, 1))
Pi_2 = np.zeros((M + 1, 1))

# %%
tt = np.linspace(0, 1, M + 1)
z[0] = z_0
S1[0] = S1_0
S2[0] = S2_0
sigma_beta = np.sqrt(sigma_1 ** 2 + beta ** 2 * sigma_2 ** 2 + 2 * beta * sigma_1 * sigma_2 * rho)
eta = (-1/delta) * (mu_1 - sigma_1 ** 2/2 + beta*(mu_2 - sigma_2 ** 2/2))
rn = np.random.standard_normal(z.shape)
rn1 = np.random.standard_normal(S1.shape) 
rn2 = np.random.standard_normal(S2.shape) 
for t in range(1, M + 1):
    z[t] = z[t-1]* (1 - delta * (eta - z[t-1])) * dt + sigma_beta * np.sqrt(dt)*((sigma_1 + beta * sigma_2 * rho)/ sigma_beta * rn1[t] + beta * (sigma_2 * np.sqrt(1-rho ** 2)/sigma_beta) * rn1[t]);
    S1[t] = BTC['Adj Close'][t-1]
    S2[t] = ETH['Adj Close'][t-1]

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, S1, 'b', lw=1.5, label='Stock 1')
plt.plot(tt, S2, 'r', lw=1.5, label='Stock 2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Stock Price')
# Out:
# Text(0.5, 1.0, 'Stock Price')

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, z, 'g', lw=1.5)
plt.xlabel('Time')
plt.ylabel('Rate')
plt.title('z')
# Out:
# Text(0.5, 1.0, 'z')

# %%
for t in range(1, M + 1):
    a[t] = 0.5 * (T - t * dt)/((1-rho ** 2) * sigma_1 ** 2)
    b[t] = - 0.25 * (T - t * dt) ** 2 * (sigma_1 ** 2 + beta * sigma_2 ** 2)/((1 - rho ** 2) * sigma_1 ** 2) - rho * mu_2 * (T - t * dt)/((1 - rho **2) * sigma_1 * sigma_2)
    c[t] = 0.5 * mu_2 ** 2 * (T - t * dt)/((1 - rho ** 2) * sigma_2 ** 2) + 0.25 * (T - t * dt) ** 2 * (sigma_1 ** 2 + beta * sigma_2 ** 2 + 2 * sigma_1 * sigma_2 * beta *rho) * delta ** 2/((1 - rho ** 2) * sigma_1 ** 2) + 0.25 * (T - t * dt) ** 2 * mu_2 * delta * rho * (sigma_1 ** 2 + beta * sigma_2 ** 2) + 1/24 * (T - t * dt) ** 3 * (sigma_1 ** 2 + beta * sigma_2 ** 2) ** 2 * delta ** 2/((1 - rho ** 2) * sigma_1 ** 2)
    Pi_1[t] = (1 / S1[t]) * ((mu_1 + delta * z[t])/(gamma * (1 - rho ** 2) * sigma_1 ** 2) + delta/gamma * (-2 * a[t] * (mu_1 + delta * z[t])-b[t]) - rho * mu_2/(gamma * (1 - rho ** 2) * sigma_1 * sigma_2))
    Pi_2[t] = (1 / S2[t]) * (mu_2 / (gamma * (1 - rho ** 2) * sigma_2 ** 2) + delta * beta / gamma * (- 2 * a[t] * (mu_1 + delta * z[t]) - b[t]) - rho * (mu_1 + delta * z[t]) / (gamma * (1 - rho ** 2) * sigma_1 * sigma_2))

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1, 'b', lw=1.5, label='w1')
plt.plot(tt, Pi_2, 'r', lw=1.5, label='w2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('%')
plt.title('Weights')
# Out:
# Text(0.5, 1.0, 'Weights')

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1 * S1, 'b', lw=1.5, label='Wealth 1')
plt.plot(tt, Pi_2 * S2, 'r', lw=1.5, label='Wealth 2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Cash')
# Out:
# Text(0.5, 1.0, 'Cash')

# %%
Wealth = abs(Pi_1 * S1) + abs(Pi_2 * S2)

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt[1:], Wealth[1:], 'b', lw=1.5, label='Total')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Wealth')
# Out:
# Text(0.5, 1.0, 'Wealth')

# %%
Wealth[1]
# Out:
# array([580.65332212])

# %%
Wealth[-1]
# Out:
# array([42.03681921])

# %%
(Wealth[-1] - Wealth[1])/Wealth[1]
# Out:
# array([-0.92760427])

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1 * S1 + Pi_2 * S2, 'b', lw=1.5, label='Dynamic')
plt.plot(tt, Pi_1.mean() * S1 + Pi_2.mean() * S2, 'r', lw=1.5, label='Static')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Comparison')
# Out:
# Text(0.5, 1.0, 'Comparison')
